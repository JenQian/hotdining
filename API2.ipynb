# %%
# Dependencies
import requests
import json
from pprint import pprint
import pandas as pd
import numpy as np

# Google developer API key
from config import API_KEY

# %%
# File to Load 
michelin_df = pd.read_csv("Resources/Michelin-Starred Restaurants.csv", encoding='utf-8')
michelin_df.head()
# Out:
#    Unnamed: 0           name              address       city state  \
# 0           1    Sushi Inoue        381 Lenox Ave   New York    NY
# 1           2       Dovetail        103 W 77th St   New York    NY
# 2           3    Cafe Boulud         20 E 76th St   New York    NY
# 3           4   Jean-Georges  1 Central Park West   New York    NY
# 4           5           Masa      10 Columbus Cir   New York    NY
#
#                                          description  star  \
# 0   ONE STAR for this Japanese restaurant in Harlem.     1
# 1  John Fraser's UWS fine dining restaurant has O...     1
# 2  Daniel Boulud's beloved Upper East Side restau...     1
# 3  Jean-Georges Vongerichten's flagship restauran...     2
# 4  Masa Takayama's pricey sushi restaurant has TH...     3
#
#                               full_address  postal_code
# 0        381 Lenox Ave, New York, NY 10027        10027
# 1        103 W 77th St, New York, NY 10024        10024
# ...

# %%
# File to Load 
michelin_rev_df = pd.read_csv("Resources/michelin_rev_df.csv", encoding='utf-8')
michelin_rev_df.head()
# Out:
#             name              address       city state  \
# 0    Sushi Inoue        381 Lenox Ave   New York    NY
# 1       Dovetail        103 W 77th St   New York    NY
# 2    Cafe Boulud         20 E 76th St   New York    NY
# 3   Jean-Georges  1 Central Park West   New York    NY
# 4           Masa      10 Columbus Cir   New York    NY
#
#                                          description  star  \
# 0   ONE STAR for this Japanese restaurant in Harlem.     1
# 1  John Fraser's UWS fine dining restaurant has O...     1
# 2  Daniel Boulud's beloved Upper East Side restau...     1
# 3  Jean-Georges Vongerichten's flagship restauran...     2
# 4  Masa Takayama's pricey sushi restaurant has TH...     3
#
#                               full_address  postal_code Reservation platform
# 0        381 Lenox Ave, New York, NY 10027        10027                 Resy
# 1        103 W 77th St, New York, NY 10024        10024                  NaN
# ...

# %%
michelin_rev_df.dtypes

# %%
# michelin_rev_df.loc[michelin_rev_df["Reservation platform"]=='NaN']
michelin_rev_df['Reservation platform'].isnull().sum()

# %%
## Checking how to get a string of words from full_address
address = michelin_rev_df['full_address']
element = address[20].split(" ")
element
# Out:
# ['13', 'E', '37th', 'St,', 'New', 'York,', 'NY', '10016']

# %%
## TESTING API RESPONSE ##
#base_url="https://maps.googleapis.com/maps/api/geocode/json?address=1600+Amphitheatre+Parkway,+Mountain+View,+CA&key=YOUR_API_KEY"

base_url = "https://maps.googleapis.com/maps/api/geocode/json?address="
api_key = f'&key={API_KEY}'

url = base_url+f'{element[0]}+{element[1]}+{element[2]}+{element[3]}+{element[4]}+{element[5]}+{element[6]}+{element[7]}'+api_key
# print(url)
response = requests.get(url).json()
pprint(response)
# Out:
# {'results': [{'address_components': [{'long_name': '13',
#                                       'short_name': '13',
#                                       'types': ['street_number']},
#                                      {'long_name': 'East 37th Street',
#                                       'short_name': 'E 37th St',
#                                       'types': ['route']},
#                                      {'long_name': 'Manhattan',
#                                       'short_name': 'Manhattan',
#                                       'types': ['political',
#                                                 'sublocality',
#                                                 'sublocality_level_1']},
#                                      {'long_name': 'New York',
#                                       'short_name': 'New York',
#                                       'types': ['locality', 'political']},
# ...

# %%
## TESTING API RESPONSE ##
response['results'][0]['geometry']['location']['lat']
# Out:
# 40.7501259

# %%
# Testing how to add up all words of full_address in a string

adding_address = ""
adding = []
element = address[19].split(" ")
addresses = []

for j in range(len(element)):
        adding_address += f'{element[j]}+'
        adding = adding_address[:-1]


# len(element)
adding
# Out:
# '400+5th+Ave+#2,+New+York,+NY+10018'

# %%
base_url = "https://maps.googleapis.com/maps/api/geocode/json?address="


url = base_url+adding+api_key
response = requests.get(url).json()
pprint(response)
# latitude = response['results'][0]['geometry']['location']['lat']
# longitude = response['results'][0]['geometry']['location']['lng']
# lat.append(latitude)
# lon.append(longitude)
# print(f'Latitude: {latitude}')
# print(f'Longitude: {longitude}')
# print(michelin_rev_df['name'][19])
# Out:
# {'error_message': 'You must use an API key to authenticate each request to '
#                   'Google Maps Platform APIs. For additional information, '
#                   'please refer to http://g.co/dev/maps-no-account',
#  'results': [],
#  'status': 'REQUEST_DENIED'}

# %%
# Creating a list of the addresses in strings to feed the API request

addresses = []

for i in range(len(address)):
    element = address[i].split(" ")
    adding_address = ""
    adding = []
    for j in range(len(element)):
        adding_address += f'{element[j]}+'
        adding = adding_address[:-1]
    addresses.append(adding)

addresses
# Out:
# ['381+Lenox+Ave,+New+York,+NY+10027',
#  '103+W+77th+St,+New+York,+NY+10024',
#  '20+E+76th+St,+New+York,+NY+10021',
#  '1+Central+Park+West,+New+York,+NY+10023',
#  '10+Columbus+Cir,+New+York,+NY+10019',
#  '240+Central+Park+S,+New+York,+NY+10019',
#  '60+E+65th+St,+New+York,+NY+10065',
#  '362+W+53rd+St,+New+York,+NY+10019',
#  '155+W+51st+St,+New+York,+NY+10019',
#  '9+W+53rd+St,+New+York,+NY+10019',
#  '65+E+55th+St,+New+York,+NY+10022',
#  '538+Madison+Ave,+New+York,+NY+10022',
#  '114+W+47th+St+(discreetly+located),+New+York,+NY+10036',
#  '431+W+37th+St,+New+York,+NY+10018',
#  '135+W+42nd+St,+New+York,+NY+10036',
#  '41+W+42nd+St,+New+York,+NY+10036',
#  '461+5th+Ave,+New+York,+NY+10017',
#  '245+E+44th+St,+New+York,+NY+10017',
#  '204+E+43rd+St,+New+York,+NY+10017',
#  '400+5th+Ave+#2,+New+York,+NY+10018',
#  '13+E+37th+St,+New+York,+NY+10016',
#  '125+E+39th+St,+New+York,+NY+10016',
#  '222+E+39th+St,+New+York,+NY+10016',
#  '362+W+23rd+St,+New+York,+NY+10011',
# ...

# %%
# Fixing Ai Fiori's address
addresses[19] = addresses[19].replace('400+5th+Ave+#2,+New+York,+NY+10018', '400+5th+Ave,+New+York,+NY+10018') 
addresses[19]
# Out:
# '400+5th+Ave,+New+York,+NY+10018'

# %%
len(addresses)
# Out:
# 72

# %%
# Performing the API requests and storing the coordinates in lists

lat =[]
lon = []

base_url = "https://maps.googleapis.com/maps/api/geocode/json?address="

for i in range(len(addresses)):
    try:
        print('===============')
        print(michelin_rev_df['name'][i])
        url = base_url+addresses[i]+"&key=AIzaSyA46ElldaT1niey5aBkvDRQ2DQCRSQgn9I"
        response = requests.get(url).json()
        latitude = response['results'][0]['geometry']['location']['lat']
        longitude = response['results'][0]['geometry']['location']['lng']
        lat.append(latitude)
        lon.append(longitude)
        print(f'Latitude: {latitude}')
        print(f'Longitude: {longitude}')
    except IndexError:
        print("There was a ERROR HERE!!!!!!!")
        continue
# Out:
# ...
#  Sushi Inoue
# Latitude: 40.8106508
# Longitude: -73.94385799999999
# ...
#  Dovetail
# Latitude: 40.7809576
# Longitude: -73.9766017
# ...
#  Cafe Boulud
# Latitude: 40.7744937
# Longitude: -73.9640958
# ...
#  Jean-Georges
# Latitude: 40.7690255
# Longitude: -73.98162549999999
# ...
#  Masa
# Latitude: 40.7685526
# Longitude: -73.9831866
# ...
#  Marea
# Latitude: 40.7674484
# Longitude: -73.9811332
# ...
#  Daniel
# Latitude: 40.7667727
# Longitude: -73.9676284
# ...
#  Torishin
# Latitude: 40.7649896
# Longitude: -73.9871924
# ...
#  Le Bernardin
# Latitude: 40.7615691
# Longitude: -73.98180479999999
# ...
#  The Modern
# Latitude: 40.7609475
# Longitude: -73.9768318
# ...
#  Aquavit
# Latitude: 40.760928
# Longitude: -73.9721295
# ...
#  Caviar Russe
# Latitude: 40.7607667
# Longitude: -73.9738498
# ...
#  Satsuki (Suzuki’s sushi bar)
# Latitude: 40.7581194
# Longitude: -73.9830293
# ...
#  Chef's Table at Brooklyn Fare
# Latitude: 40.7561226
# Longitude: -73.9964617
# ...
#  Aureole
# Latitude: 40.7555597
# Longitude: -73.9853213
# ...
#  Gabriel Kreuther
# ...

# %%
print(f'Length of lat is {len(lat)} and that of lon is {len(lon)}')
# Out:
# Length of lat is 72 and that of lon is 72

# %%
print(lat)

# %%
names = []

restaurants = michelin_rev_df['name']

for i in range(len(restaurants)):
    resto = restaurants[i]
    names.append(resto)

# %%
address = []

for i in range(len(restaurants)):
    location = michelin_df['full_address'][i]
    address.append(location)

# address

# %%
stars = []

for i in range(len(restaurants)):
    star = michelin_df['star'][i]
    stars.append(star)
    
stars = list(map(int, stars))

# %%
data_set = {"restaurants": [names],
            "stars": [stars],
           "latitude": [lat], 
           "longitude": [lon],
           "address": [address]}

# %%
json_dump = json.dumps(data_set)
print(json_dump)

# %%
with open('./Resources/coordinates_good.json', 'w', encoding='utf-8') as f:
    json.dump(data_set, f, ensure_ascii=False, indent=4)

# %%
from pprint import pprint

json_dump

# %%
for i in range(len(restaurants)):
    print("{")
    print(f'"formatted_address" : "{address[i]}"'+",")
    print(f'"geometry" : '+ "{")
    print(f'  "location" :'+ "{")
    print(f'     "lat" : {lat[i]}' + ",")
    print(f'     "lon" : {lon[i]}')
    print("    } ")
    print("  }, ")
#     print(f'"michelin_stars" : "{stars[i]}"'+",")
    print(f'"name" : "{names[i]}"'+",")
    print("}, ")
    print(" ")

# %%
import sys

orig_stdout = sys.stdout
f = open('Resources/the_one.txt', 'w')
sys.stdout = f

for i in range(len(restaurants)):
    print("{")
    print(f' "formatted_address" : "{address[i]}"'+",")
    print(f' "geometry" : '+ "{")
    print(f'   "location" :'+ " {")
    print(f'      "lat" : {lat[i]}' + ",")
    print(f'      "lng" : {lon[i]}')
    print("    } ")
    print("  }, ")
#     print(f'"michelin_stars" : "{stars[i]}"'+",")
    print(f' "name" : "{names[i]}"'+",")
    print("}, ")
    print(" ")

sys.stdout = orig_stdout
f.close()

# %%
# with open("Resources/the_one.txt") as f:
#     json_dump = json.dumps(f, ensure_ascii=False, indent=4)

# print(json_dump)

# %%
#### INTENDED RESULT #####

"results" : [
      {
         "formatted_address" : "1 Central Park West, New York, NY 10023, United States",
         "geometry" : {
            "location" : {
               "lat" : 40.769084,
               "lng" : -73.981431
            }
         },

         "name" : "Jean-Georges",
      },
