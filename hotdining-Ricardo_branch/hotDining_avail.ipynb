# %% [markdown]
# Hot Dining

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from datetime import date

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

engine = create_engine('sqlite://', echo=False)
connection = engine.connect()

# %%
michelin_df= pd.read_csv('Michelin-Starred Restaurants.csv')

# %%
michelin_df
# Out:
#     Unnamed: 0             name  \
# 0            1      Sushi Inoue
# 1            2         Dovetail
# 2            3      Cafe Boulud
# 3            4     Jean-Georges
# 4            5             Masa
# ..         ...              ...
# 67          70   The River Café
# 68          71          La Vara
# 69          72        The Finch
# 70           6           Per Se
# 71          18            Agern
#
#                                            address       city state  \
# 0                                    381 Lenox Ave   New York    NY
# 1                                    103 W 77th St   New York    NY
# 2                                     20 E 76th St   New York    NY
# 3                              1 Central Park West   New York    NY
# 4                                  10 Columbus Cir   New York    NY
# ..                                             ...        ...   ...
# 67                                      1 Water St   Brooklyn    NY
# ...

# %%
# Convert to SQL
michelin_df.to_sql('users', con=engine, if_exists="replace")

# %%
# Import Dependencies
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv

nRowsRead = 1000 # specify 'None' if want to read whole file
df1 = pd.read_csv('Michelin-Starred Restaurants.csv', delimiter=',', nrows = nRowsRead)
df1.dataframeName = 'Michelin-Starred Restaurants.csv'
nRow, nCol = df1.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 72 rows and 9 columns

# %%
# Create a SQL Database
from sqlalchemy import create_engine
engine = create_engine('sqlite:///restaurants.sqlite', echo=False)

# Convert to SQL
michelin_df.to_sql('restaurants', con=engine, if_exists="replace")

# %%
# Import scrapting dependencies
from bs4 import BeautifulSoup
import requests
from splinter import Browser
#from selenium import webdriver

# %%
date.today().strftime("%Y-%m-%d")
# Out:
# '2020-03-07'

# %%
#Resy
executable_path = {'executable_path': '/Users/jeqian/Documents/DA Bootcamp/CU-NYC-DATA-PT-10-2019-U-C/chromedriver'}
browser = Browser('chrome', **executable_path, headless=True,user_agent="Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36")
resy_url = 'https://resy.com/cities/ny/the-modern?date=2020-03-07&seats=2'
browser.visit(resy_url)
#testing = first_found = browser.find_by_name('styled__AvailabilityDayWrapper').first
#print
# browser.click_link_by_partial_text('FULL IMAGE')
# browser.click_link_by_partial_text('more info')
resy_html = browser.html
resy_soup = BeautifulSoup(resy_html, 'html.parser')
print(resy_soup.prettify())
#resy_path = resy_soup.find(class_='ResyInlineBooking')
#browser.click_link_by_partial_text('next article arrow')
# Out:
# <html class="js smil" lang="en" ng-app="resyApp" ng-strict-di="">
#  <head>
#   <style type="text/css">
#    .uib-position-measure{display:block !important;visibility:hidden !important;position:absolute !important;top:-9999px !important;left:-9999px !important;}.uib-position-scrollbar-measure{position:absolute !important;top:-9999px !important;width:50px !important;height:50px !important;overflow:scroll !important;}.uib-position-body-scrollbar-measure{overflow:scroll !important;}
#   </style>
#   <style type="text/css">
#    @charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}
#   </style>
#   <base href="/"/>
#   <title ng-bind="metadata.title">
#    Book Your The Modern Reservation With Resy
#   </title>
#   <meta charset="utf-8"/>
# ...

# %%
resy_path = resy_soup.find_all(class_='ResyInlineBooking__wrapper--service')

# %%
resy_path[0].find_all('div', class_="time")
# Out:
# [<div class="time">5:00PM</div>,
#  <div class="time">5:15PM</div>,
#  <div class="time">5:30PM</div>,
#  <div class="time">5:45PM</div>,
#  <div class="time">9:45PM</div>,
#  <div class="time">10:00PM</div>]

# %%
import functools
import operator

# %%
times = [ times.text for times in functools.reduce(operator.iconcat, [res.find_all('div', class_="time") for res in resy_path], [])]

# %%
times
# Out:
# ['5:00PM', '5:15PM', '5:30PM', '5:45PM', '9:45PM', '10:00PM']

# %%
#ExploreStock

executable_path = {'executable_path': '/Users/jeqian/Documents/DA Bootcamp/CU-NYC-DATA-PT-10-2019-U-C/chromedriver'}
browser = Browser('chrome', **executable_path, headless=True,user_agent="Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36")
exp_url = 'https://www.exploretock.com/bluehillatstonebarns/experience/47900/?cameFrom=search_modal&date=2020-03-08&size=2&time=19%3A00'
browser.visit(exp_url)
#testing = first_found = browser.find_by_name('styled__AvailabilityDayWrapper').first
#print
# browser.click_link_by_partial_text('FULL IMAGE')
# browser.click_link_by_partial_text('more info')
exp_html = browser.html
exp_soup = BeautifulSoup(exp_html, 'html.parser')
print(exp_soup.prettify())
# Out:
# <html class="no-js" data-useragent="Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"/>
#   <meta content="QUyvrVcAk0TqgIRdEO1fbw8fQD4XdOsZzYhpZuT_yI0" name="google-site-verification"/>
#   <link href="https://www.exploretock.com/assets/favicon/v4/apple-touch-icon-57x57.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
#   <link href="https://www.exploretock.com/assets/favicon/v4/apple-touch-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <link href="https://www.exploretock.com/assets/favicon/v4/apple-touch-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# ...

# %%
exp_soup.find_all(class_="Consumer-resultsListItem is-available Consumer-resultsListItem--wide")
# Out:
# []

# %%
#Open Table

executable_path = {'executable_path': '/Users/jeqian/Documents/DA Bootcamp/CU-NYC-DATA-PT-10-2019-U-C/chromedriver'}
browser = Browser('chrome', **executable_path, headless=True,user_agent="Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.122 Safari/537.36")
op_url = 'https://www.opentable.com/restref/client/?restref=337&partysize=2&datetime=2020-03-16T19%3A30&lang=en-US&corrid=7c9022d0-6287-487a-a43c-b8d23e9a012b'
browser.visit(op_url)
#testing = first_found = browser.find_by_name('styled__AvailabilityDayWrapper').first
#print
# browser.click_link_by_partial_text('FULL IMAGE')
# browser.click_link_by_partial_text('more info')
op_html = browser.html
op_soup = BeautifulSoup(op_html, 'html.parser')
print(op_soup.prettify())
# Out:
# <html lang="en-US">
#  <head>
#   <meta content="IE=9; IE=8; IE=7; IE=EDGE" http-equiv="X-UA-Compatible"/>
#   <title>
#    Daniel Online Reservations | OpenTable
#   </title>
#   <meta content="Instantly reserve a table at Daniel in New York / Tri-State Area. Free online reservations anytime, anywhere." name="description"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="noindex, nofollow" name="robots"/>
#   <link href="//cdn.otstatic.com/restref-site/css/../css/client.8c705fd30a808ce913eb.css" rel="stylesheet" type="text/css"/>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="//consent.truste.com/notice?domain=opentable.com&amp;c=teconsent&amp;js=bb&amp;noticeType=bb&amp;text=true" type="text/javascript">
#   </script>
# ...

# %%
times = [times.text for times in op_soup.find_all(class_="styled__Wrapper-sc-1q1dpdt-4 cJaqmE")[0].find_all("button") ]

# %%
times = [ times.text for times in functools.reduce(operator.iconcat, [res.find_all('div', class_="time") for res in resy_path], [])]
